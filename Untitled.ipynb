# %%
import numpy as np
import pandas as pd
#import tensorflow as tf
import matplotlib.pyplot as plt

from scipy.signal import savgol_filter
from IPython.display import display

# %%
path_to_data = 'Данные СТМ Восточный Купол (от 29.01.17)\Куст 201\Скважина 2011.xlsx'

# %%
# чтение данных и файла и возврат датафрейма
def get_df(path):
    file = pd.read_excel(path)
    file.rename(columns = {'Unnamed: 0' : 'Time Moment'}, inplace = True)
    file = file.drop(labels = [0], axis = 0) # удалить вторую строку оглавления
    return file

# %%
# вывести график 4 переменных относительно времени
def draw_4_graphs(df):
    plt.figure(figsize=(22, 20))
    i = 1
    
    for col_name, data in df.items():
        if i != 1:
            plt.subplot(4, 1, i-1)
            #plt.plot(df['Time Moment'].values, data.values, '-')
            plt.plot(df['Time Moment'] , data, '-')
            #plt.xticks(rotation = 45)
            plt.title(col_name)
        i+=1

    plt.show()

# %%
def draw_4_graphs_for_frewuencis(df):
    columns = list(df.columns[1:])
    i = 1
    
    plt.figure(figsize=(16, 10))
    
    for col_name in columns:
        plt.subplot(2, 2, i)
        df[col_name].plot(kind='hist', density=1, bins=20, stacked=False, alpha=.5, color='grey')
        plt.title(col_name)
        i+=1
        
    plt.show()

# %%
# стандартизация данных
def standartize_data(df):
    i = True
    for col_name, data in df.items():
        if col_name != 'Time Moment': 
            df[col_name] = df[col_name] / df[col_name].max()
    return df

# %%
# подготовка данных
def prepare_data(df):
    print("Before processing: ", df.shape)
    
    columns = list(df.columns[1:])
    
    # удаление пропусков
    df.dropna(inplace = True)    
    print("After NAN delete: ", df.shape)
    
    # удаление нулей
    #df = df.drop(labels = [0], axis = 0)
    for col in columns:
        df = df.loc[df[col] != 0]
    '''df = df.loc[df['Time Moment'] != 0]
    df = df.loc[df['PT2011-202 (Давление до УР)'] != 0]
    df = df.loc[df['PT2011-204 (Давление после УР)'] != 0]
    df = df.loc[df['TT2011-101 (Температура в ТП до УР)'] != 0]
    df = df.loc[df['FT2011-301-1 (Расход в ТП до УР)'] != 0]'''
    print("After 0 delete: ", df.shape)
    
    # удаление выбросов
    '''Q1 =  df['TT2011-101 (Температура в ТП до УР)'].quantile(0.25)
    Q3 = df['TT2011-101 (Температура в ТП до УР)'].quantile(0.75)
    IQR = Q3 - Q1
    df.query("@Q1 - 1.5*@IQR < y < @Q3 + 1.5*@IQR").boxplot(column="y")'''
    
    '''columns = list(df.columns[1:])
    
    for col in columns:
        Q1 =  df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1
        df_IQR = df[(df[col] > (Q1-1.5*IQR)) & (df[col] < (Q3+1.5*IQR))]
        df_IQR.boxplot(column = col)'''
    
    for col in columns:
        print('\nФильтрация по: ', col)
        row_before = df.shape[0]
        Q1 =  df[col].quantile(0.025)
        Q3 = df[col].quantile(0.975)
        IQR = Q3 - Q1
        #display(df[(df[col] < Q1) | (df[col] > Q3)])
        df = df[(df[col] > (Q1-1.5*IQR)) & (df[col] < (Q3+1.5*IQR))]
        print('Удалено строк: ', row_before - df.shape[0], "\n")
    
    #print(df.dtypes)
    
    #columns = list(df.columns[1:4])
    #print("\n", columns, "\n")
    
    #df.boxplot(column = columns) # рисование для всех числовых колонок
    
    print("After emissions delete: ", df.shape)
    
    return df

# %%
# описаниие данных
def describe_data(df):
    # вывод общей инфы о каждой колонке
    display(df.describe())
    
    columns = list(df.columns[1:])
    
    # вывод графиков частоты встречающихся значений
    draw_4_graphs_for_frewuencis(df)
    
    # вывод таблицы с редко встречающимися значениями (они же выбросы)
    #df_IQR = df
    
    '''for col in columns:
        print('\nФильтрация по: ', col)
        Q1 =  df[col].quantile(0.025)
        Q3 = df[col].quantile(0.975)
        IQR = Q3 - Q1
        display(df[(df[col] < Q1) | (df[col] > Q3)])'''
        #df_IQR = df_IQR[(df_IQR[col] > (Q1-1.5*IQR)) & (df_IQR[col] < (Q3+1.5*IQR))]
    
    # вывод графиков частоты встречающихся значений для таблицы без выбрасов
    #print("\nFinal data")
    #display(df_IQR)
    #draw_4_graphs_for_frewuencis(df_IQR)
    
    
    
    #df[columns[3]].plot(kind='hist', density=1, bins=20, stacked=False, alpha=.5, color='grey')
    #plt.title(columns[3])
    
    #Q1 =  df[col].quantile(0.025)
    #Q3 = df[col].quantile(0.975)
    #display(df[(df[col] < Q1) | (df[col] > Q3)])

# %%
# чтение данных и приведение столбцов к нужным типам данных
firstDF = get_df(path_to_data)

print(firstDF.dtypes)

columns = list(df.columns[1:])
for col in columns:
        firstDF[col] = firstDF[col].astype(float)
'''        
firstDF['PT2011-202 (Давление до УР)'] = firstDF['PT2011-202 (Давление до УР)'].astype(float)
firstDF['PT2011-204 (Давление после УР)'] = firstDF['PT2011-204 (Давление после УР)'].astype(float)
firstDF['TT2011-101 (Температура в ТП до УР)'] = firstDF['TT2011-101 (Температура в ТП до УР)'].astype(float)
firstDF['FT2011-301-1 (Расход в ТП до УР)'] = firstDF['FT2011-301-1 (Расход в ТП до УР)'].astype(float)'''

print("\n", firstDF.dtypes)

print(firstDF.shape)
# удалить нулевые значения - (предполагается что в эти моменты прпиборы измерения выключены)

'''
print(type(firstDF.loc[1,'c']))
print(type(firstDF.loc[1,'PT2011-202 (Давление до УР)']))
print(type(firstDF.loc[1,'PT2011-204 (Давление после УР)']))
print(type(firstDF.loc[1,'TT2011-101 (Температура в ТП до УР)']))
print(type(firstDF.loc[1,'FT2011-301-1 (Расход в ТП до УР)']))'''
#display(firstDF)
#firstDF = firstDF.drop(labels = [0], axis = 0)


#print(firstDF.shape)

display(firstDF)
# Out:
# Time Moment                            object
# PT2011-202 (Давление до УР)            object
# PT2011-204 (Давление после УР)         object
# TT2011-101 (Температура в ТП до УР)    object
# FT2011-301-1 (Расход в ТП до УР)       object
# dtype: object
# Time Moment                             object
# PT2011-202 (Давление до УР)            float64
# PT2011-204 (Давление после УР)         float64
# TT2011-101 (Температура в ТП до УР)    float64
# FT2011-301-1 (Расход в ТП до УР)       float64
# dtype: object
# (9361, 5)
#               Time Moment  PT2011-202 (Давление до УР)  \
# 1     2014-12-11 00:00:00                   116.536697
# 2     2014-12-11 02:00:00                   115.591301
# 3     2014-12-11 04:00:00                   115.929298
# 4     2014-12-11 06:00:00                   116.546501
# 5     2014-12-11 08:00:00                   116.198700
# ...                   ...                          ...
# 9357  2017-01-28 16:00:00                    82.166397
# 9358  2017-01-28 18:00:00                    82.132118
# 9359  2017-01-28 20:00:00                    82.318237
# 9360  2017-01-28 22:00:00                    82.337837
# 9361  2017-01-29 00:00:00                    82.401512
#
#       PT2011-204 (Давление после УР)  TT2011-101 (Температура в ТП до УР)  \
# 1                         112.045097                            46.856258
# 2                         112.103897                            46.859692
# 3                         112.182198                            46.880291
# 4                         112.275299                            46.918060
# 5                         112.329201                            46.918060
# ...                              ...                                  ...
# 9357                       82.470093                            45.321579
# 9358                       82.445587                            45.163651
# 9359                       82.612129                            45.187691
# 9360                       82.631721                            45.249489
# 9361                       82.714996                            45.397110
#
#       FT2011-301-1 (Расход в ТП до УР)
# 1                         55716.488281
# 2                         55215.261719
# 3                         55229.570312
# 4                         55462.929688
# 5                         55315.988281
# ...                                ...
# 9357                      22623.039062
# 9358                      22638.109375
# 9359                      22611.640625
# 9360                      22575.789062
# 9361                      22646.710938
#
# [9361 rows x 5 columns]

# %%
# Вывод графика изменения ошибки
'''
plt.plot(firstDF['Unnamed: 0'].values, firstDF['PT2011-202 (Давление до УР)'].values)
plt.plot(firstDF['Unnamed: 0'].values, firstDF['PT2011-204 (Давление после УР)'].values)
#plt.plot(firstDF['Unnamed: 0'].values, firstDF['FT2011-301-1 (Расход в ТП до УР)'].values)
#plt.plot(firstDF['PT2011-202 (Давление до УР)'].values, firstDF['PT2011-204 (Давление после УР)'].values)
plt.title('Давление')
plt.ylabel('Давление после')
plt.xlabel('Давление до')
plt.legend(['Давление до', 'Давление после'], loc = 'upper left')
plt.show()'''

'''
x = firstDF['Unnamed: 0'].values
y1 = firstDF['PT2011-202 (Давление до УР)'].values
y2 = firstDF['PT2011-204 (Давление после УР)'].values
y3 = firstDF['TT2011-101 (Температура в ТП до УР)'].values
y4 = firstDF['FT2011-301-1 (Расход в ТП до УР)'].values'''

# визуализация и описание данных до подготовки
describe_data(firstDF)

draw_4_graphs(firstDF)
# Out:
#        PT2011-202 (Давление до УР)  PT2011-204 (Давление после УР)  \
# count                  9292.000000                     9292.000000
# mean                    106.055068                      104.252704
# std                      18.184290                       13.657690
# min                      -0.421241                       -0.308583
# 25%                      99.074799                       99.873009
# 50%                     108.768200                      107.898849
# 75%                     114.137823                      112.157799
# max                     173.482498                      162.270706
#
#        TT2011-101 (Температура в ТП до УР)  FT2011-301-1 (Расход в ТП до УР)
# count                          9292.000000                       9292.000000
# mean                             47.489140                      31441.511229
# std                               3.805488                       9277.163173
# min                             -50.000000                          0.000000
# 25%                              46.904320                      25154.277344
# 50%                              48.095680                      27602.485352
# 75%                              48.861301                      37332.399414
# max                              50.231178                     127115.898438

# %%
# подготовка данных
Prepared_DF = prepare_data(firstDF)
# Out:
# Before processing:  (9361, 5)
# After NAN delete:  (9292, 5)
# After 0 delete:  (9280, 5)
#
# Фильтрация по:  PT2011-202 (Давление до УР)
# Удалено строк:  33
#
#
# Фильтрация по:  PT2011-204 (Давление после УР)
# Удалено строк:  35
#
#
# Фильтрация по:  TT2011-101 (Температура в ТП до УР)
# Удалено строк:  33
#
#
# Фильтрация по:  FT2011-301-1 (Расход в ТП до УР)
# Удалено строк:  0
#
# After emissions delete:  (9179, 5)

# %%
# визуализация и описание подготовленных данных
describe_data(Prepared_DF)
draw_4_graphs(Prepared_DF)
# Out:
#        PT2011-202 (Давление до УР)  PT2011-204 (Давление после УР)  \
# count                  9179.000000                     9179.000000
# mean                    106.670486                      104.841485
# std                      15.684636                       10.119691
# min                      22.737190                       82.406410
# 25%                      99.417671                       99.968712
# 50%                     108.827003                      107.984497
# 75%                     114.114548                      112.152901
# max                     173.482498                      161.286194
#
#        TT2011-101 (Температура в ТП до УР)  FT2011-301-1 (Расход в ТП до УР)
# count                          9179.000000                       9179.000000
# mean                             47.865280                      31729.839687
# std                               1.154550                       8653.859733
# min                              39.886700                          5.582912
# 25%                              46.959259                      25184.344727
# 50%                              48.112839                      28156.089844
# 75%                              48.868160                      37395.580078
# max                              50.231178                      71294.703125

# %%
#y_filt_1 = savgol_filter(firstDF['PT2011-202 (Давление до УР)'].values, 61, 3)
#y_filt_2 = savgol_filter(firstDF['PT2011-204 (Давление после УР)'].values, 61, 3)

# %%
# стандартизация данных + визуализация и описание
Standartised_DF = standartize_data(Prepared_DF)
describe_data(Prepared_DF)
draw_4_graphs(Prepared_DF)
# Out:
#        PT2011-202 (Давление до УР)  PT2011-204 (Давление после УР)  \
# count                  9179.000000                     9179.000000
# mean                      0.614878                        0.650034
# std                       0.090410                        0.062744
# min                       0.131063                        0.510933
# 25%                       0.573070                        0.619822
# 50%                       0.627308                        0.669521
# 75%                       0.657787                        0.695366
# max                       1.000000                        1.000000
#
#        TT2011-101 (Температура в ТП до УР)  FT2011-301-1 (Расход в ТП до УР)
# count                          9179.000000                       9179.000000
# mean                              0.952900                          0.445052
# std                               0.022985                          0.121382
# min                               0.794063                          0.000078
# 25%                               0.934863                          0.353243
# 50%                               0.957828                          0.394925
# 75%                               0.972865                          0.524521
# max                               1.000000                          1.000000

# %%
# Вывод графика изменения ошибки
#print(firstDF.shape)
#prepare_data(firstDF)
#firstDF = standartize_data(firstDF)

# %%
#draw_4_graphs(firstDF)

# %%
#подсчет коэффициентов корелляции
'''pressure_before = np.array(firstDF['PT2011-202 (Давление до УР)'].values, dtype = float)
pressure_after =  np.array(firstDF['PT2011-204 (Давление после УР)'].values, dtype = float)
temperature = np.array(firstDF['TT2011-101 (Температура в ТП до УР)'].values, dtype = float)
consumption = np.array(firstDF['FT2011-301-1 (Расход в ТП до УР)'].values, dtype = float)'''

#cor_arr = np.array(SecondDF)

#cor_arr =  np.array(firstDF.drop(['Time Moment'], axis=1), dtype = float)

#display(firstDF)
#a = np.array([1,2,3,4,5,6], dtype = float)
#b = np.array([6,7,5,4,2,1], dtype = float)

#print(np.corrcoef(cor_arr))

'''print(type(pressure_before))
print(type(pressure_after))
print(type(temperature))
print(type(consumption))

print(f"correl pressure_before and pressure_after: ", np.corrcoef(pressure_before, pressure_after))
print(f"correl pressure_before and temperature: {np.corrcoef(pressure_before, temperature)}")
print(f"correl pressure_before and consumption: {np.corrcoef(pressure_before, consumption)}")

print(f"correl pressure_after and temperature: {np.corrcoef(pressure_after, temperature)}")
print(f"correl pressure_after and consumption: {np.corrcoef(pressure_after, consumption)}")

print(f"correl temperature and consumption: {np.corrcoef(temperature, consumption)}")'''
# Out:
# 'print(type(pressure_before))\nprint(type(pressure_after))\nprint(type(temperature))\nprint(type(consumption))\n\nprint(f"correl pressure_before and pressure_after: ", np.corrcoef(pressure_before, pressure_after))\nprint(f"correl pressure_before and temperature: {np.corrcoef(pressure_before, temperature)}")\nprint(f"correl pressure_before and consumption: {np.corrcoef(pressure_before, consumption)}")\n\nprint(f"correl pressure_after and temperature: {np.corrcoef(pressure_after, temperature)}")\nprint(f"correl pressure_after and consumption: {np.corrcoef(pressure_after, consumption)}")\n\nprint(f"correl temperature and consumption: {np.corrcoef(temperature, consumption)}")'

# %%
#np.array?
'''
plt.plot(pressure_before, pressure_after, '-')
plt.title("Зависимости давлений")
plt.xlabel('Давление до')
plt.ylabel('Давление после')
plt.show()'''
# Out:
# '\nplt.plot(pressure_before, pressure_after, \'-\')\nplt.title("Зависимости давлений")\nplt.xlabel(\'Давление до\')\nplt.ylabel(\'Давление после\')\nplt.show()'
